# %%
import pandas as pd
dataset=pd.read_csv(r'\Users\MARIAM\OneDrive\Desktop\ADV AI\archive\Salary Data.csv')
dataset.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
X = dataset.iloc[:, :-1].values    # Features => Years of experience => Independent Variable
y = dataset.iloc[:, -1].values     # Target => Salary => Dependent Variable

X
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(y_pred)

print(y_test)
# Out:
# [ 40817.78327049 123188.08258899  65154.46261459  63282.41035735
#  115699.87356004 108211.66453108 116635.89968866  64218.43648597
#   76386.77615802]
# [ 37731. 122391.  57081.  63218. 116969. 109431. 112635.  55794.  83088.]

# %%
import matplotlib.pyplot as plt
plt.scatter(X_train, y_train, color='red')
plt.plot(X_train, model.predict(X_train))

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
err=mean_absolute_error(y_test,y_pred)
err2=mean_squared_error(y_test,y_pred)
print(err)
print(err2)
# Out:
# 3737.4178618788987
# 23370078.800832972
